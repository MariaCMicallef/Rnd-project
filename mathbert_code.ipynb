# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
import json
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn

# %%
train_path = 'numerical_measuremental_conceptual_train.json'
dev_path = 'numerical_measuremental_conceptual_dev.json'
test_path = 'numerical_measuremental_conceptual_test.json'
train_json = open(train_path)
dev_json = open(dev_path)
test_json = open(test_path)
train_data = json.load(train_json)
dev_data = json.load(dev_json)
test_data = json.load(test_json)

# %%
from transformers import BertForMultipleChoice, BertTokenizer, AutoTokenizer
#tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', use_fast = True)
mathtokenizer = AutoTokenizer.from_pretrained('tbs17/MathBERT-custom', use_fast= True)
#modelmulti = BertForMultipleChoice.from_pretrained('bert-base-uncased')
#modelmultimath = BertForMultipleChoice.from_pretrained('tbs17/MathBERT-custom')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/569 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def format_data(dataset):
  questions = []
  choices = []
  answers = []
  numerical = []
  measuremental = []
  conceptual = []
  total = 0
  have_all = 0
  o1 = 0
  o2 = 0
  for entry in dataset:
    total += 1
    if 'numerical_explanation' in entry.keys() and 'measuremental_explanation' in entry.keys() and 'conceptual_explanation' in entry.keys():
      numerical.append(entry['numerical_explanation'])
      measuremental.append(entry['measuremental_explanation'])
      conceptual.append(entry['conceptual_explanation'])
      questions.append(entry['question'])
      choices.append([entry['Option1'], entry['Option2']])
      if entry['answer'] == 'Option 1':
        answers.append(entry['Option1'])
        o1 += 1
      elif entry['answer'] == 'Option 2':
        answers.append(entry['Option2'])
        o2+= 1

      have_all += 1
  print(f'{have_all} entries used out of {total}. {(total-have_all)*100/total} of data was removed. {o1} entries had option 1 as an answer and {o2} entries had question 2 as an answer')
  return questions, choices, answers, numerical, measuremental, conceptual

# %%
train_questions, train_choices, train_answers, train_numerical, train_measuremental, train_conceptual = format_data(train_data)
dev_questions, dev_choices, dev_answers, dev_numerical, dev_measuremental, dev_conceptual = format_data(dev_data)
test_questions, test_choices, test_answers, test_numerical, test_measuremental, test_conceptual = format_data(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d3809417f3d> in <cell line: 2>()
#       1 #using
# ----> 2 train_questions, train_choices, train_answers, train_numerical, train_measuremental, train_conceptual = format_data(train_data)
#       3 dev_questions, dev_choices, dev_answers, dev_numerical, dev_measuremental, dev_conceptual = format_data(dev_data)
#       4 test_questions, test_choices, test_answers, test_numerical, test_measuremental, test_conceptual = format_data(test_data)
#
# NameError: name 'format_data' is not defined

# %%
def all_tokenizer(questions, choices, answers, tokenizer, numerical, measuremental, conceptual):
  one_choices = []
  one_questions = []
  numerical_explanations = []
  measuremental_explanations = []
  conceptual_explanations = []
  labels = []
  pairs = []
  for i in range(len(questions)):
    question = questions[i]
    if numerical != None:
      question = f'{question} {numerical[i]}'
    if measuremental != None:
      question = f'{question} {measuremental[i]}'
    if conceptual != None:
      question = f'{question} {conceptual[i]}'
    one_question = [question, question]
    one_choice = [f"{choice}" for choice in choices[i]]# input sequence: question ans1 question ans2

    one_questions.append(one_question)
    one_choices.append(one_choice)
    if i == 0:
      print(one_choice)
    labels.append(return_label(choices[i], answers[i]))#since 2 possible choices. if answer is o1, it's [0, 0] if o2 it's [1, 1]
    pair = tokenizer(one_question, one_choice, max_length=512, truncation=False, padding=True, return_tensors='pt')
    pairs.append(pair)
  keys = ['input_ids', 'attention_mask']
  print(pairs[0]['input_ids'].size())
  max_length = 512
  for ix, p in enumerate(pairs):
    assert len(p['input_ids']) == 2
    assert len(p['input_ids'][0]) == len(p['input_ids'][1])
    padding_length = max_length - len(p['input_ids'][0])
    if len(p['input_ids'][0]) >= 512:
      print(f'Question with index {ix}, with numerical_explanations {numerical}, measuremental_explanations {measuremental} and conceptual_explanations {conceptual} is at least 512 tokens long')
      raise Exception
    p['input_ids'] = torch.cat([p['input_ids'], torch.zeros((2, padding_length), dtype=torch.long)], dim=1)
    p['attention_mask'] = torch.cat([p['attention_mask'], torch.zeros((2, padding_length), dtype=torch.long)], dim=1)

  tokenized_examples = {}
  for k in keys:
    tokenized_examples[k] = torch.cat([p[k] for p in pairs], dim=0)
  num_samples = len(tokenized_examples['input_ids'])
  num_questions = num_samples//2
  print(num_samples/2, num_samples//2)
  print(len(questions))
  labels_tensor = torch.tensor(labels)
  print('labelstensor size', labels_tensor.size())
  print('tokenizedexamples inputids size', tokenized_examples['input_ids'].size())
  dictionary_context_to_questions = {
        'input_ids': tokenized_examples['input_ids'].view(num_questions, 2, -1),
        'attention_mask': tokenized_examples['attention_mask'].view(num_questions, 2, -1),
    }
  print('dictionarycontexttoquestions size', dictionary_context_to_questions['input_ids'].size())
  return dictionary_context_to_questions, labels_tensor

def return_label(choice_pair, correct_answer):
  if correct_answer == choice_pair[0]:
    return 0
  elif correct_answer == choice_pair[1]:
    return 1
  else:
    raise Exception

# %%
'''bu_train_preprocessed_b, bu_train_labels_b = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, None, None, None)
bu_dev_preprocessed_b, bu_dev_labels_b = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, None, None, None)
bu_test_preprocessed_b, bu_test_labels_b = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, None, None, None)

bu_train_preprocessed_n, bu_train_labels_n = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, train_numerical, None, None)
bu_dev_preprocessed_n, bu_dev_labels_n = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, dev_numerical, None, None)
bu_test_preprocessed_n, bu_test_labels_n = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, test_numerical, None, None)

bu_train_preprocessed_m, bu_train_labels_m = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, None, train_measuremental, None)
bu_dev_preprocessed_m, bu_dev_labels_m = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, None, dev_measuremental, None)
bu_test_preprocessed_m, bu_test_labels_m = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, None, test_measuremental, None)

bu_train_preprocessed_c, bu_train_labels_c = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, None, None, train_conceptual)
bu_dev_preprocessed_c, bu_dev_labels_c = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, None, None, dev_conceptual)
bu_test_preprocessed_c, bu_test_labels_c = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, None, None, test_conceptual)

bu_train_preprocessed_nm, bu_train_labels_nm = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, train_numerical, train_measuremental, None)
bu_dev_preprocessed_nm, bu_dev_labels_nm = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, dev_numerical, dev_measuremental, None)
bu_test_preprocessed_nm, bu_test_labels_nm = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, test_numerical, test_measuremental, None)

bu_train_preprocessed_nmc, bu_train_labels_nmc = all_tokenizer(train_questions, train_choices, train_answers, tokenizer, train_numerical, train_measuremental, train_conceptual)
bu_dev_preprocessed_nmc, bu_dev_labels_nmc = all_tokenizer(dev_questions, dev_choices, dev_answers, tokenizer, dev_numerical, dev_measuremental, dev_conceptual)
bu_test_preprocessed_nmc, bu_test_labels_nmc = all_tokenizer(test_questions, test_choices, test_answers, tokenizer, test_numerical, test_measuremental, test_conceptual)'''

# %%
train_preprocessed_b, train_labels_b = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, None, None, None)
dev_preprocessed_b, dev_labels_b = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, None, None, None)
test_preprocessed_b, test_labels_b = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, None, None, None)

train_preprocessed_n, train_labels_n = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, train_numerical, None, None)
dev_preprocessed_n, dev_labels_n = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, dev_numerical, None, None)
test_preprocessed_n, test_labels_n = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, test_numerical, None, None)

train_preprocessed_m, train_labels_m = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, None, train_measuremental, None)
dev_preprocessed_m, dev_labels_m = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, None, dev_measuremental, None)
test_preprocessed_m, test_labels_m = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, None, test_measuremental, None)

train_preprocessed_c, train_labels_c = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, None, None, train_conceptual)
dev_preprocessed_c, dev_labels_c = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, None, None, dev_conceptual)
test_preprocessed_c, test_labels_c = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, None, None, test_conceptual)

train_preprocessed_nm, train_labels_nm = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, train_numerical, train_measuremental, None)
dev_preprocessed_nm, dev_labels_nm = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, dev_numerical, dev_measuremental, None)
test_preprocessed_nm, test_labels_nm = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, test_numerical, test_measuremental, None)

train_preprocessed_nmc, train_labels_nmc = all_tokenizer(train_questions, train_choices, train_answers, mathtokenizer, train_numerical, train_measuremental, train_conceptual)
dev_preprocessed_nmc, dev_labels_nmc = all_tokenizer(dev_questions, dev_choices, dev_answers, mathtokenizer, dev_numerical, dev_measuremental, dev_conceptual)
test_preprocessed_nmc, test_labels_nmc = all_tokenizer(test_questions, test_choices, test_answers, mathtokenizer, test_numerical, test_measuremental, test_conceptual)
# Out:
# ['rottweiler', 'greyhound']
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2632: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# torch.Size([2, 40])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 43])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 42])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])
# ['rottweiler', 'greyhound']
# torch.Size([2, 46])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 49])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 58])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])
# ['rottweiler', 'greyhound']
# torch.Size([2, 51])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 51])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 66])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])
# ['rottweiler', 'greyhound']
# torch.Size([2, 61])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 64])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 62])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])
# ['rottweiler', 'greyhound']
# torch.Size([2, 57])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 57])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 82])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])
# ['rottweiler', 'greyhound']
# torch.Size([2, 78])
# 537.0 537
# 537
# labelstensor size torch.Size([537])
# tokenizedexamples inputids size torch.Size([1074, 512])
# dictionarycontexttoquestions size torch.Size([537, 2, 512])
# ['the mountain was farther away', 'Jane was farther away']
# torch.Size([2, 78])
# 67.0 67
# 67
# labelstensor size torch.Size([67])
# tokenizedexamples inputids size torch.Size([134, 512])
# dictionarycontexttoquestions size torch.Size([67, 2, 512])
# ['Tina', 'Maria']
# torch.Size([2, 102])
# 153.0 153
# 153
# labelstensor size torch.Size([153])
# tokenizedexamples inputids size torch.Size([306, 512])
# dictionarycontexttoquestions size torch.Size([153, 2, 512])

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, BertForMultipleChoice, get_linear_schedule_with_warmup
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
import copy

class BertMultipleChoiceFineTuner:
    def __init__(self, model, model_name, lr, num_epochs=30, batch_size=8):
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.lr = lr
        if model == 'math':
            self.model = BertForMultipleChoice.from_pretrained('tbs17/MathBERT-custom')
        elif model == 'base':
            self.model = BertForMultipleChoice.from_pretrained('bert-base-uncased')
        else:
            raise Exception


        self.optimizer = torch.optim.AdamW(self.model.parameters(), lr=self.lr)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model.to(self.device)
        self.model_name = model_name





    def train(self, train_dictionary_context_to_questions, train_labels, dev_dictionary_context_to_questions, dev_labels):
        all_accuracies = []

        train_input_ids = train_dictionary_context_to_questions['input_ids']
        train_attention_masks = train_dictionary_context_to_questions['attention_mask']

        dev_input_ids = dev_dictionary_context_to_questions['input_ids']
        dev_attention_masks = dev_dictionary_context_to_questions['attention_mask']

        train_labels = train_labels.flatten()
        dev_labels = dev_labels.flatten()

        train_dataset = TensorDataset(train_input_ids, train_attention_masks, train_labels)
        dev_dataset = TensorDataset(dev_input_ids, dev_attention_masks, dev_labels)

        train_dataloader = DataLoader(train_dataset, batch_size=self.batch_size, shuffle=True)
        dev_dataloader = DataLoader(dev_dataset, batch_size=self.batch_size)
        total_steps = len(train_dataloader) * self.num_epochs


        self.model.train()

        for epoch in range(self.num_epochs):
            total_train_loss = 0
            total_train_correct = 0

            for batch in train_dataloader:
                batch = tuple(t.to(self.device) for t in batch)
                input_ids, attention_mask, labels = batch

                self.optimizer.zero_grad()
                outputs = self.model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)#batch size is 8. despite for loop going through batches, the input_ids of all the batches are all entered in at once.
                loss = outputs.loss
                total_train_loss += loss.item()

                logits = outputs.logits
                _, predicted = torch.max(logits, 1)
                total_train_correct += (predicted == labels).sum().item()

                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), 0.1)#parameters above the number are set to the num, prevents them from becoming too high

                self.optimizer.step()
            average_train_loss = total_train_loss / len(train_dataloader)
            accuracy = total_train_correct / len(train_dataset)
            model_state = {'epoch': epoch, 'model_state_dict': self.model.state_dict(), 'optimizer_state_dict': self.optimizer.state_dict()}
            model_filename = f'{self.model_name}_epoch_{epoch}_lr_{self.lr}.pt'
            torch.save(model_state, model_filename)
            del model_state

            self.model.eval()
            total_dev_loss = 0
            total_dev_correct = 0

            for batch in dev_dataloader:
                batch = tuple(t.to(self.device) for t in batch)
                input_ids, attention_mask, labels = batch

                with torch.no_grad():
                    outputs = self.model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
                    loss = outputs.loss
                    total_dev_loss += loss.item()

                    logits = outputs.logits
                    _, predicted = torch.max(logits, 1)
                    total_dev_correct += (predicted == labels).sum().item()

            average_dev_loss = total_dev_loss / len(dev_dataloader)
            dev_accuracy = total_dev_correct / len(dev_dataset)
            all_accuracies.append(dev_accuracy)
            print(f'Epoch {epoch + 1}/{self.num_epochs} - Average Train Loss: {average_train_loss:.4f} with accuracy {accuracy} - Average Dev Loss: {average_dev_loss:.4f} with accuracy {dev_accuracy}')
        best = max(all_accuracies)
        best_epoch = all_accuracies.index(best)
        return best, best_epoch, self.lr


    def test(self, test_dictionary_context_to_questions, test_labels):
      test_input_ids = test_dictionary_context_to_questions['input_ids']
      test_attention_masks = test_dictionary_context_to_questions['attention_mask']

      test_labels = test_labels.flatten()
      test_dataset = TensorDataset(test_input_ids, test_attention_masks, test_labels)
      test_dataloader = DataLoader(test_dataset, batch_size=self.batch_size, shuffle=False)
      self.model.eval()
      total_test_loss = 0
      total_test_correct = 0
      total_predictions = []
      total_labels = []
      total_input_ids = []

      for batch in test_dataloader:
          batch = tuple(t.to(self.device) for t in batch)
          input_ids, attention_mask, labels = batch

          with torch.no_grad():
              outputs = self.model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
              loss = outputs.loss
              print(type(outputs))
              total_test_loss += loss.item()

              logits = outputs.logits
              _, predicted = torch.max(logits, 1)
              total_input_ids.append(input_ids)
              total_predictions.append(predicted)
              total_labels.append(labels)
              print('increase in test correct', (predicted == labels).sum())
              total_test_correct += (predicted == labels).sum().item()

      average_test_loss = total_test_loss / len(test_dataloader)
      test_accuracy = total_test_correct / len(test_dataset)
      print(f'Loss on test set is {average_test_loss} and accuracy is {test_accuracy}')
      return total_predictions, total_input_ids, total_labels

# %%
#goes through the learning rates, makes and trains models with each learning
#rate. For each model, deletes all the checkpoints except the one with the best
#accuracy. At the end notes which lr resulted in the best accuracy.
#Based on part 4 of Dr Fredrik Wahlberg's code (https://github.com/fredrikwahlberg/5LN708/blob/master/Assignment%2001%20-%20Sentiment%20Polarity%20on%20Film%20Reviews.ipynb)
def compare_lrs(model_func, bert_model, name, train, train_labels, dev, dev_labels):
  lrs = [6e-6, 2e-6, 8e-7, 5e-7, 1e-7, 8e-8]
  best_lr = None
  print("Learning rate:\tTraining set accuracy\t Dev set accuracy:")
  num_epochs = 17

  for lr in lrs:
    print(lr)
    test_model = BertMultipleChoiceFineTuner(bert_model, name, lr=lr, num_epochs = num_epochs)
    best_accuracy, best_epoch, lrprinted = test_model.train(train, train_labels, dev, dev_labels)
    for ep in range(num_epochs):
      if ep != best_epoch:
        file_name = f'{name}_epoch_{ep}_lr_{lrprinted}.pt'
        print(file_name)
        # !rm {file_name}
    with open('bestepochrecord.txt', 'a') as f3:
      print(f'Best epoch for lr {lrprinted} is {best_epoch} with dev accuracy {best_accuracy}', file=f3)
    print(f'Best epoch for lr {lrprinted} is {best_epoch} with dev accuracy {best_accuracy}')
    if test_model:
      del test_model

    if best_lr is None or best_lr[0] < best_accuracy:
      best_lr = (best_accuracy, best_epoch, lrprinted)

  print(f"Best model for {name} is the one with lr {best_lr[0]}, with dev accuracy {best_lr[0]} at epoch {best_lr[1]}")
  with open('bestmodelrecord.txt', 'a') as f2:
    print(f"Best model for {name} is the one with lr {best_lr[0]}, with dev accuracy {best_lr[0]} at epoch {best_lr[1]}", file=f2)

# %%
import numpy as np
print('math_none_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_none_no_dev_explanations', train_preprocessed_b, train_labels_b, dev_preprocessed_b, dev_labels_b)

# %%
print('math_n_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_n_no_dev_explanations', train_preprocessed_n, train_labels_n, dev_preprocessed_b, dev_labels_b)

# %%
print('math_m_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_m_no_dev_explanations', train_preprocessed_m, train_labels_m, dev_preprocessed_b, dev_labels_b)

# %%
print('math_c_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_c_no_dev_explanations', train_preprocessed_c, train_labels_c, dev_preprocessed_b, dev_labels_b)

# %%
print('math_nm_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_nm_no_dev_explanations', train_preprocessed_nm, train_labels_nm, dev_preprocessed_b, dev_labels_b)

# %%
print('math_nmc_no_dev_explanations')
compare_lrs(BertMultipleChoiceFineTuner, 'math', 'math_nmc_no_dev_explanations', train_preprocessed_nmc, train_labels_nmc, dev_preprocessed_b, dev_labels_b)

# %%
from google.colab import runtime
runtime.unassign()

# %%
#trains a model with the provided learning rate, deletes all checkpoints except the best one (to save space) and tests the data on the best epoch
def train_model(model_func, bert_model, name, train_data, train_labels, dev_data, dev_labels, lr, num_epochs=25):
  test_model = BertMultipleChoiceFineTuner(bert_model, name, lr=lr, num_epochs = num_epochs)
  best_accuracy, best_epoch, lrprinted = test_model.train(train_data, train_labels, dev_data, dev_labels)#train_questions, train_choices, train_answers, dev_questions, dev_choices, dev_answers)
  best_epoch = int(input(f'Currently, best_epoch is {best_epoch} starting from 0. Enter the epoch you want to use (reenter the best epoch to use that)'))
  return best_epoch, name, num_epochs, lrprinted, test_model

def test_model_func(best_epoch, name, num_epochs, lrprinted, test_model, test_data, test_labels, tokenizer):
  for ep in range(num_epochs):
    if ep != best_epoch:
      file_name = f'{name}_epoch_{ep}_lr_{lrprinted}.pt'
      print(file_name)
      # !rm {file_name}
  with open('bestepochrecord.txt', 'a') as f3:
    print(f'Best epoch for {name} with lr {lrprinted} is {best_epoch}', file=f3)
  print(f'Best epoch for lr {lrprinted} is {best_epoch}')
  checkpoint = torch.load(f'{name}_epoch_{best_epoch}_lr_{lrprinted}.pt')
  test_model.model.load_state_dict(checkpoint['model_state_dict'])
  total_predictions, total_input_ids, total_labels = test_model.test(test_data, test_labels)
  extended_ids = []
  extended_labels = []
  extended_predictions = []
  answers = []
  for batch_list in total_input_ids:
    extended_ids.extend(batch_list)
  for batch_labels in total_labels:
    extended_labels.extend(batch_labels)
  for batch_answers in total_predictions:
    extended_predictions.extend(batch_answers)
  for i, entry in enumerate(extended_ids):
    first_q = entry[0]
    first_q = tokenizer.decode(first_q)
    first_q = first_q.split('[SEP]')
    question = first_q[0]
    choice_1 = first_q[1]
    second_q= entry[1]
    second_q = tokenizer.decode(second_q)
    second_q = second_q.split('[SEP]')
    choice_2 = second_q[1]
    prediction = extended_predictions[i].item()
    label = extended_labels[i].item()
    answer = question, choice_1, choice_2, prediction, label
    answers.append(answer)

  with open(f'{name}_result_data.txt', 'w') as f:
    for entr in answers:
      print(entr, file=f)
  if test_model:
      del test_model

# %%
import numpy as np
print('math_none_no_dev_explanations')
b_epoch, b_name, b_num_epochs, b_lrprinted, b_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_none_no_dev_explanations', train_preprocessed_b, train_labels_b, dev_preprocessed_b, dev_labels_b, lr=6e-6)
test_model_func(b_epoch, b_name, b_num_epochs, b_lrprinted, b_model, test_preprocessed_b, test_labels_b, mathtokenizer)
# Out:
# math_none_no_dev_explanations
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at tbs17/MathBERT-custom and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/25 - Average Train Loss: 0.6998 with accuracy 0.4972067039106145 - Average Dev Loss: 0.6938 with accuracy 0.5223880597014925
# Epoch 2/25 - Average Train Loss: 0.6874 with accuracy 0.553072625698324 - Average Dev Loss: 0.6942 with accuracy 0.582089552238806
# Epoch 3/25 - Average Train Loss: 0.6516 with accuracy 0.6238361266294227 - Average Dev Loss: 0.7029 with accuracy 0.47761194029850745
# Epoch 4/25 - Average Train Loss: 0.6076 with accuracy 0.6722532588454376 - Average Dev Loss: 0.6993 with accuracy 0.5522388059701493
# Epoch 5/25 - Average Train Loss: 0.5561 with accuracy 0.7299813780260708 - Average Dev Loss: 0.7319 with accuracy 0.44776119402985076
# Epoch 6/25 - Average Train Loss: 0.5134 with accuracy 0.7635009310986964 - Average Dev Loss: 0.7259 with accuracy 0.5223880597014925
# Epoch 7/25 - Average Train Loss: 0.4797 with accuracy 0.7635009310986964 - Average Dev Loss: 0.7117 with accuracy 0.5671641791044776
# Epoch 8/25 - Average Train Loss: 0.4437 with accuracy 0.7783985102420856 - Average Dev Loss: 0.7443 with accuracy 0.44776119402985076
# Epoch 9/25 - Average Train Loss: 0.4329 with accuracy 0.7914338919925512 - Average Dev Loss: 0.7466 with accuracy 0.5373134328358209
# Epoch 10/25 - Average Train Loss: 0.4119 with accuracy 0.8081936685288641 - Average Dev Loss: 0.7666 with accuracy 0.5223880597014925
# Epoch 11/25 - Average Train Loss: 0.3857 with accuracy 0.8119180633147114 - Average Dev Loss: 0.7735 with accuracy 0.5074626865671642
# Epoch 12/25 - Average Train Loss: 0.3746 with accuracy 0.8249534450651769 - Average Dev Loss: 0.8270 with accuracy 0.5223880597014925
# Epoch 13/25 - Average Train Loss: 0.3438 with accuracy 0.8379888268156425 - Average Dev Loss: 0.7796 with accuracy 0.5074626865671642
# Epoch 14/25 - Average Train Loss: 0.3323 with accuracy 0.8491620111731844 - Average Dev Loss: 0.8522 with accuracy 0.47761194029850745
# Epoch 15/25 - Average Train Loss: 0.2998 with accuracy 0.851024208566108 - Average Dev Loss: 0.8442 with accuracy 0.5671641791044776
# Epoch 16/25 - Average Train Loss: 0.2954 with accuracy 0.8696461824953445 - Average Dev Loss: 0.8968 with accuracy 0.5074626865671642
# Epoch 17/25 - Average Train Loss: 0.2579 with accuracy 0.8770949720670391 - Average Dev Loss: 0.9173 with accuracy 0.4925373134328358
# Epoch 18/25 - Average Train Loss: 0.2387 with accuracy 0.888268156424581 - Average Dev Loss: 0.9158 with accuracy 0.47761194029850745
# Epoch 19/25 - Average Train Loss: 0.2358 with accuracy 0.8901303538175046 - Average Dev Loss: 0.9608 with accuracy 0.47761194029850745
# Epoch 20/25 - Average Train Loss: 0.1939 with accuracy 0.9013035381750466 - Average Dev Loss: 0.9834 with accuracy 0.5522388059701493
# Epoch 21/25 - Average Train Loss: 0.2141 with accuracy 0.9050279329608939 - Average Dev Loss: 0.8787 with accuracy 0.6417910447761194
# Epoch 22/25 - Average Train Loss: 0.1977 with accuracy 0.9143389199255121 - Average Dev Loss: 1.0718 with accuracy 0.5522388059701493
# Epoch 23/25 - Average Train Loss: 0.1608 with accuracy 0.9273743016759777 - Average Dev Loss: 1.0921 with accuracy 0.5671641791044776
# Epoch 24/25 - Average Train Loss: 0.1523 with accuracy 0.9366852886405959 - Average Dev Loss: 1.2619 with accuracy 0.47761194029850745
# Epoch 25/25 - Average Train Loss: 0.1203 with accuracy 0.9478584729981379 - Average Dev Loss: 1.4379 with accuracy 0.5522388059701493
# Currently, best_epoch is 20 starting from 0. Enter the epoch you want to use (reenter the best epoch to use that)20
# math_none_no_dev_explanations_epoch_0_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_1_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_2_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_3_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_4_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_5_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_6_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_7_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_8_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_9_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_10_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_11_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_12_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_13_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_14_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_15_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_16_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_17_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_18_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_19_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_21_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_22_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_23_lr_6e-06.pt
# math_none_no_dev_explanations_epoch_24_lr_6e-06.pt
# Best epoch for lr 6e-06 is 20
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(1, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(0, device='cuda:0')
# Loss on test set is 1.65523764193058 and accuracy is 0.477124183006536

# %%
print('math_n_no_dev_explanations')
n_epoch, n_name, n_num_epochs, n_lrprinted, n_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_n_no_dev_explanations', train_preprocessed_n, train_labels_n, dev_preprocessed_b, dev_labels_b, lr=5e-7)
test_model_func(n_epoch, n_name, n_num_epochs, n_lrprinted, n_model, test_preprocessed_b, test_labels_b, mathtokenizer)

# %%
print('math_m_no_dev_explanations')
m_epoch, m_name, m_num_epochs, m_lrprinted, m_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_m_no_dev_explanations', train_preprocessed_m, train_labels_m, dev_preprocessed_b, dev_labels_b, lr=1e-7)
test_model_func(m_epoch, m_name, m_num_epochs, m_lrprinted, m_model, test_preprocessed_b, test_labels_b, mathtokenizer)

# %%
print('math_c_no_dev_explanations')
c_epoch, c_name, c_num_epochs, c_lrprinted, c_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_c_no_dev_explanations', train_preprocessed_c, train_labels_c, dev_preprocessed_b, dev_labels_b, lr=2e-6)
test_model_func(c_epoch, c_name, c_num_epochs, c_lrprinted, c_model, test_preprocessed_b, test_labels_b, mathtokenizer)
# Out:
# math_c_no_dev_explanations
# pytorch_model.bin:   0%|          | 0.00/441M [00:00<?, ?B/s]
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at tbs17/MathBERT-custom and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/25 - Average Train Loss: 0.6937 with accuracy 0.515828677839851 - Average Dev Loss: 0.6958 with accuracy 0.4626865671641791
# Epoch 2/25 - Average Train Loss: 0.6927 with accuracy 0.5381750465549349 - Average Dev Loss: 0.6948 with accuracy 0.5373134328358209
# Epoch 3/25 - Average Train Loss: 0.6840 with accuracy 0.6536312849162011 - Average Dev Loss: 0.6964 with accuracy 0.5074626865671642
# Epoch 4/25 - Average Train Loss: 0.6636 with accuracy 0.6629422718808193 - Average Dev Loss: 0.6958 with accuracy 0.4925373134328358
# Epoch 5/25 - Average Train Loss: 0.6241 with accuracy 0.7001862197392924 - Average Dev Loss: 0.7020 with accuracy 0.47761194029850745
# Epoch 6/25 - Average Train Loss: 0.5881 with accuracy 0.7057728119180633 - Average Dev Loss: 0.7075 with accuracy 0.5373134328358209
# Epoch 7/25 - Average Train Loss: 0.5617 with accuracy 0.74487895716946 - Average Dev Loss: 0.7133 with accuracy 0.5373134328358209
# Epoch 8/25 - Average Train Loss: 0.5287 with accuracy 0.7299813780260708 - Average Dev Loss: 0.7230 with accuracy 0.5373134328358209
# Epoch 9/25 - Average Train Loss: 0.4908 with accuracy 0.7597765363128491 - Average Dev Loss: 0.7278 with accuracy 0.4925373134328358
# Epoch 10/25 - Average Train Loss: 0.4837 with accuracy 0.7560521415270018 - Average Dev Loss: 0.7295 with accuracy 0.5223880597014925
# Epoch 11/25 - Average Train Loss: 0.4776 with accuracy 0.776536312849162 - Average Dev Loss: 0.7353 with accuracy 0.4925373134328358
# Epoch 12/25 - Average Train Loss: 0.4538 with accuracy 0.7914338919925512 - Average Dev Loss: 0.7254 with accuracy 0.47761194029850745
# Epoch 13/25 - Average Train Loss: 0.4320 with accuracy 0.7932960893854749 - Average Dev Loss: 0.7370 with accuracy 0.43283582089552236
# Epoch 14/25 - Average Train Loss: 0.4129 with accuracy 0.8081936685288641 - Average Dev Loss: 0.7480 with accuracy 0.4925373134328358
# Epoch 15/25 - Average Train Loss: 0.4070 with accuracy 0.7988826815642458 - Average Dev Loss: 0.7280 with accuracy 0.44776119402985076
# Epoch 16/25 - Average Train Loss: 0.3981 with accuracy 0.7895716945996276 - Average Dev Loss: 0.7907 with accuracy 0.4925373134328358
# Epoch 17/25 - Average Train Loss: 0.3839 with accuracy 0.8156424581005587 - Average Dev Loss: 0.7440 with accuracy 0.44776119402985076
# Epoch 18/25 - Average Train Loss: 0.3710 with accuracy 0.819366852886406 - Average Dev Loss: 0.8004 with accuracy 0.4925373134328358
# Epoch 19/25 - Average Train Loss: 0.3587 with accuracy 0.8081936685288641 - Average Dev Loss: 0.8021 with accuracy 0.5373134328358209
# Epoch 20/25 - Average Train Loss: 0.3639 with accuracy 0.8286778398510242 - Average Dev Loss: 0.7934 with accuracy 0.47761194029850745
# Epoch 21/25 - Average Train Loss: 0.3649 with accuracy 0.819366852886406 - Average Dev Loss: 0.8034 with accuracy 0.4925373134328358
# Epoch 22/25 - Average Train Loss: 0.3430 with accuracy 0.8417132216014898 - Average Dev Loss: 0.7716 with accuracy 0.4925373134328358
# Epoch 23/25 - Average Train Loss: 0.3773 with accuracy 0.8417132216014898 - Average Dev Loss: 0.7987 with accuracy 0.47761194029850745
# Epoch 24/25 - Average Train Loss: 0.3218 with accuracy 0.8156424581005587 - Average Dev Loss: 0.7955 with accuracy 0.43283582089552236
# Epoch 25/25 - Average Train Loss: 0.3240 with accuracy 0.8324022346368715 - Average Dev Loss: 0.7848 with accuracy 0.47761194029850745
# Currently, best_epoch is 1 starting from 0. Enter the epoch you want to use (reenter the best epoch to use that)18
# math_c_no_dev_explanations_epoch_0_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_1_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_2_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_3_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_4_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_5_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_6_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_7_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_8_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_9_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_10_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_11_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_12_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_13_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_14_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_15_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_16_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_17_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_19_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_20_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_21_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_22_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_23_lr_2e-06.pt
# math_c_no_dev_explanations_epoch_24_lr_2e-06.pt
# Best epoch for lr 2e-06 is 18
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(2, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(0, device='cuda:0')
# Loss on test set is 0.8990220367908478 and accuracy is 0.45098039215686275

# %%
print('math_nm_no_dev_explanations')
nm_epoch, nm_name, nm_num_epochs, nm_lrprinted, nm_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_nm_no_dev_explanations', train_preprocessed_nm, train_labels_nm, dev_preprocessed_b, dev_labels_b, lr=6e-6)
test_model_func(nm_epoch, nm_name, nm_num_epochs, nm_lrprinted, nm_model, test_preprocessed_b, test_labels_b, mathtokenizer)
# Out:
# math_nm_no_dev_explanations
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at tbs17/MathBERT-custom and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/25 - Average Train Loss: 0.6904 with accuracy 0.5381750465549349 - Average Dev Loss: 0.6912 with accuracy 0.5970149253731343
# Epoch 2/25 - Average Train Loss: 0.6908 with accuracy 0.5344506517690876 - Average Dev Loss: 0.6934 with accuracy 0.5373134328358209
# Epoch 3/25 - Average Train Loss: 0.6493 with accuracy 0.6927374301675978 - Average Dev Loss: 0.6881 with accuracy 0.5970149253731343
# Epoch 4/25 - Average Train Loss: 0.5768 with accuracy 0.7262569832402235 - Average Dev Loss: 0.6883 with accuracy 0.6716417910447762
# Epoch 5/25 - Average Train Loss: 0.5118 with accuracy 0.7839851024208566 - Average Dev Loss: 0.7463 with accuracy 0.582089552238806
# Epoch 6/25 - Average Train Loss: 0.4179 with accuracy 0.8156424581005587 - Average Dev Loss: 0.7533 with accuracy 0.5522388059701493
# Epoch 7/25 - Average Train Loss: 0.3722 with accuracy 0.839851024208566 - Average Dev Loss: 0.7349 with accuracy 0.5373134328358209
# Epoch 8/25 - Average Train Loss: 0.3266 with accuracy 0.8417132216014898 - Average Dev Loss: 0.7658 with accuracy 0.582089552238806
# Epoch 9/25 - Average Train Loss: 0.2873 with accuracy 0.8640595903165735 - Average Dev Loss: 0.8436 with accuracy 0.5373134328358209
# Epoch 10/25 - Average Train Loss: 0.2482 with accuracy 0.8715083798882681 - Average Dev Loss: 0.9260 with accuracy 0.5522388059701493
# Epoch 11/25 - Average Train Loss: 0.2130 with accuracy 0.888268156424581 - Average Dev Loss: 0.8909 with accuracy 0.6119402985074627
# Epoch 12/25 - Average Train Loss: 0.1931 with accuracy 0.9068901303538175 - Average Dev Loss: 1.0019 with accuracy 0.582089552238806
# Epoch 13/25 - Average Train Loss: 0.1600 with accuracy 0.9217877094972067 - Average Dev Loss: 0.9252 with accuracy 0.5970149253731343
# Epoch 14/25 - Average Train Loss: 0.1329 with accuracy 0.9422718808193669 - Average Dev Loss: 0.8531 with accuracy 0.5671641791044776
# Epoch 15/25 - Average Train Loss: 0.1115 with accuracy 0.9441340782122905 - Average Dev Loss: 1.0726 with accuracy 0.5671641791044776
# Epoch 16/25 - Average Train Loss: 0.0843 with accuracy 0.9664804469273743 - Average Dev Loss: 1.2761 with accuracy 0.47761194029850745
# Epoch 17/25 - Average Train Loss: 0.0672 with accuracy 0.9720670391061452 - Average Dev Loss: 1.3293 with accuracy 0.5373134328358209
# Epoch 18/25 - Average Train Loss: 0.0586 with accuracy 0.9795158286778398 - Average Dev Loss: 1.3016 with accuracy 0.5522388059701493
# Epoch 19/25 - Average Train Loss: 0.0373 with accuracy 0.9888268156424581 - Average Dev Loss: 1.4160 with accuracy 0.5373134328358209
# Epoch 20/25 - Average Train Loss: 0.0163 with accuracy 0.994413407821229 - Average Dev Loss: 1.3844 with accuracy 0.5522388059701493
# Epoch 21/25 - Average Train Loss: 0.0167 with accuracy 0.994413407821229 - Average Dev Loss: 1.6050 with accuracy 0.5373134328358209
# Epoch 22/25 - Average Train Loss: 0.0295 with accuracy 0.9925512104283054 - Average Dev Loss: 1.5046 with accuracy 0.5074626865671642
# Epoch 23/25 - Average Train Loss: 0.0084 with accuracy 0.9962756052141527 - Average Dev Loss: 1.6535 with accuracy 0.47761194029850745
# Epoch 24/25 - Average Train Loss: 0.0180 with accuracy 0.994413407821229 - Average Dev Loss: 1.5766 with accuracy 0.5223880597014925
# Epoch 25/25 - Average Train Loss: 0.0107 with accuracy 0.994413407821229 - Average Dev Loss: 1.6707 with accuracy 0.5074626865671642
# Currently, best_epoch is 3 starting from 0. Enter the epoch you want to use (reenter the best epoch to use that)3
# math_nm_no_dev_explanations_epoch_0_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_1_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_2_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_4_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_5_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_6_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_7_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_8_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_9_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_10_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_11_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_12_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_13_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_14_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_15_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_16_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_17_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_18_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_19_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_20_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_21_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_22_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_23_lr_6e-06.pt
# math_nm_no_dev_explanations_epoch_24_lr_6e-06.pt
# Best epoch for lr 6e-06 is 3
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(1, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(2, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(2, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(0, device='cuda:0')
# Loss on test set is 0.6995626091957092 and accuracy is 0.5032679738562091

# %%
print('math_nmc_no_dev_explanations')
nmc_epoch, nmc_name, nmc_num_epochs, nmc_lrprinted, nmc_model = train_model(BertMultipleChoiceFineTuner, 'math', 'math_nmc_no_dev_explanations', train_preprocessed_nmc, train_labels_nmc, dev_preprocessed_b, dev_labels_b, lr=8e-8)
test_model_func(nmc_epoch, nmc_name, nmc_num_epochs, nmc_lrprinted, nmc_model, test_preprocessed_b, test_labels_b, mathtokenizer)
# Out:
# math_nmc_no_dev_explanations
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at tbs17/MathBERT-custom and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/25 - Average Train Loss: 0.6946 with accuracy 0.4934823091247672 - Average Dev Loss: 0.6939 with accuracy 0.5373134328358209
# Epoch 2/25 - Average Train Loss: 0.6932 with accuracy 0.5027932960893855 - Average Dev Loss: 0.6938 with accuracy 0.5522388059701493
# Epoch 3/25 - Average Train Loss: 0.6930 with accuracy 0.5027932960893855 - Average Dev Loss: 0.6937 with accuracy 0.5522388059701493
# Epoch 4/25 - Average Train Loss: 0.6928 with accuracy 0.5232774674115456 - Average Dev Loss: 0.6936 with accuracy 0.5522388059701493
# Epoch 5/25 - Average Train Loss: 0.6924 with accuracy 0.5363128491620112 - Average Dev Loss: 0.6935 with accuracy 0.5522388059701493
# Epoch 6/25 - Average Train Loss: 0.6921 with accuracy 0.5493482309124768 - Average Dev Loss: 0.6934 with accuracy 0.5522388059701493
# Epoch 7/25 - Average Train Loss: 0.6918 with accuracy 0.5679702048417132 - Average Dev Loss: 0.6933 with accuracy 0.5671641791044776
# Epoch 8/25 - Average Train Loss: 0.6915 with accuracy 0.5754189944134078 - Average Dev Loss: 0.6932 with accuracy 0.5671641791044776
# Epoch 9/25 - Average Train Loss: 0.6912 with accuracy 0.5791433891992551 - Average Dev Loss: 0.6931 with accuracy 0.5671641791044776
# Epoch 10/25 - Average Train Loss: 0.6909 with accuracy 0.595903165735568 - Average Dev Loss: 0.6930 with accuracy 0.5671641791044776
# Epoch 11/25 - Average Train Loss: 0.6906 with accuracy 0.6108007448789572 - Average Dev Loss: 0.6929 with accuracy 0.5671641791044776
# Epoch 12/25 - Average Train Loss: 0.6901 with accuracy 0.6108007448789572 - Average Dev Loss: 0.6928 with accuracy 0.5671641791044776
# Epoch 13/25 - Average Train Loss: 0.6896 with accuracy 0.6163873370577281 - Average Dev Loss: 0.6927 with accuracy 0.5671641791044776
# Epoch 14/25 - Average Train Loss: 0.6891 with accuracy 0.6238361266294227 - Average Dev Loss: 0.6926 with accuracy 0.582089552238806
# Epoch 15/25 - Average Train Loss: 0.6887 with accuracy 0.62756052141527 - Average Dev Loss: 0.6925 with accuracy 0.582089552238806
# Epoch 16/25 - Average Train Loss: 0.6881 with accuracy 0.6350093109869647 - Average Dev Loss: 0.6925 with accuracy 0.582089552238806
# Epoch 17/25 - Average Train Loss: 0.6877 with accuracy 0.6368715083798883 - Average Dev Loss: 0.6924 with accuracy 0.582089552238806
# Epoch 18/25 - Average Train Loss: 0.6871 with accuracy 0.6443202979515829 - Average Dev Loss: 0.6923 with accuracy 0.582089552238806
# Epoch 19/25 - Average Train Loss: 0.6866 with accuracy 0.6499068901303539 - Average Dev Loss: 0.6922 with accuracy 0.5671641791044776
# Epoch 20/25 - Average Train Loss: 0.6858 with accuracy 0.6573556797020484 - Average Dev Loss: 0.6922 with accuracy 0.5522388059701493
# Epoch 21/25 - Average Train Loss: 0.6852 with accuracy 0.6573556797020484 - Average Dev Loss: 0.6921 with accuracy 0.5522388059701493
# Epoch 22/25 - Average Train Loss: 0.6845 with accuracy 0.6573556797020484 - Average Dev Loss: 0.6921 with accuracy 0.5522388059701493
# Epoch 23/25 - Average Train Loss: 0.6839 with accuracy 0.6610800744878957 - Average Dev Loss: 0.6921 with accuracy 0.5522388059701493
# Epoch 24/25 - Average Train Loss: 0.6835 with accuracy 0.6666666666666666 - Average Dev Loss: 0.6920 with accuracy 0.5671641791044776
# Epoch 25/25 - Average Train Loss: 0.6813 with accuracy 0.6685288640595903 - Average Dev Loss: 0.6921 with accuracy 0.5671641791044776
# Currently, best_epoch is 13 starting from 0. Enter the epoch you want to use (reenter the best epoch to use that)17
# math_nmc_no_dev_explanations_epoch_0_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_1_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_2_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_3_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_4_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_5_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_6_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_7_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_8_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_9_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_10_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_11_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_12_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_13_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_14_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_15_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_16_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_18_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_19_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_20_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_21_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_22_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_23_lr_8e-08.pt
# math_nmc_no_dev_explanations_epoch_24_lr_8e-08.pt
# Best epoch for lr 8e-08 is 17
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(2, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(1, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(2, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(7, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(3, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(5, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(6, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(4, device='cuda:0')
# <class 'transformers.modeling_outputs.MultipleChoiceModelOutput'>
# increase in test correct tensor(1, device='cuda:0')
# Loss on test set is 0.6924927473068238 and accuracy is 0.5228758169934641
